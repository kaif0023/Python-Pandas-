# %% [markdown]
# ### Missing Values and Deleting Data points
#
#
#
# ### Step 1. Import the necessary libraries numpy, pandas etc

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset *wine.txt* from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data) or from the folder

# %% [markdown]
# ### Step 3. Assign it to a variable called wine
#
# Please note that the original data text file doesn't contain any header. Please ensure that when you import the data, you should use a suitable argument so as to avoid data getting imported as header.

# %%
wine = pd.read_csv("C://Users//md kaif//Downloads//wine.data",names=["a","b","c","d","e","f","g","h","i","j","k","l","m","n"])
wine
# Out:
#      a      b     c     d     e    f     g     h     i     j      k     l  \
# 0    1  14.23  1.71  2.43  15.6  127  2.80  3.06  0.28  2.29   5.64  1.04
# 1    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 2    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 3    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 4    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 173  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 174  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 175  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 176  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 177  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#         m     n
# 0    3.92  1065
# 1    3.40  1050
# 2    3.17  1185
# 3    3.45  1480
# 4    2.93   735
# ..    ...   ...
# 173  1.74   740
# 174  1.56   750
# 175  1.56   835
# 176  1.62   840
# 177  1.60   560
#
# [178 rows x 14 columns]

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine.drop(columns=["a","d","g","i","k","m","n"],inplace=True)

# %%
wine
# Out:
#          b     c     e    f     h     j     l
# 0    14.23  1.71  15.6  127  3.06  2.29  1.04
# 1    13.20  1.78  11.2  100  2.76  1.28  1.05
# 2    13.16  2.36  18.6  101  3.24  2.81  1.03
# 3    14.37  1.95  16.8  113  3.49  2.18  0.86
# 4    13.24  2.59  21.0  118  2.69  1.82  1.04
# ..     ...   ...   ...  ...   ...   ...   ...
# 173  13.71  5.65  20.5   95  0.61  1.06  0.64
# 174  13.40  3.91  23.0  102  0.75  1.41  0.70
# 175  13.27  4.28  20.0  120  0.69  1.35  0.59
# 176  13.17  2.59  20.0  120  0.68  1.46  0.60
# 177  14.13  4.10  24.5   96  0.76  1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.rename(columns={'b':'alcohol','c':'malic_acid','e':'alcalinity_of_ash','f':'magnesium','h':'flavanoids','j':'proanthocyanins','l':'hue'},inplace=True)

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      14.23        1.71               15.6        127        3.06
# 1      13.20        1.78               11.2        100        2.76
# 2      13.16        2.36               18.6        101        3.24
# 3      14.37        1.95               16.8        113        3.49
# 4      13.24        2.59               21.0        118        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5         95        0.61
# 174    13.40        3.91               23.0        102        0.75
# 175    13.27        4.28               20.0        120        0.69
# 176    13.17        2.59               20.0        120        0.68
# 177    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### Step 6. Set the values of the first 3 values from alcohol column as NaN

# %%
wine["alcohol"].replace(14.23,np.nan,inplace=True)
wine["alcohol"].replace(13.20,np.nan,inplace=True)
wine["alcohol"].replace(13.16,np.nan,inplace=True)
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.71               15.6        127        3.06
# 1        NaN        1.78               11.2        100        2.76
# 2        NaN        2.36               18.6        101        3.24
# 3      14.37        1.95               16.8        113        3.49
# 4      13.24        2.59               21.0        118        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5         95        0.61
# 174    13.40        3.91               23.0        102        0.75
# 175    13.27        4.28               20.0        120        0.69
# 176    13.17        2.59               20.0        120        0.68
# 177    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine["magnesium"].replace(101,np.nan,inplace=True)
wine["magnesium"].replace(113,np.nan,inplace=True)

# %%
wine["magnesium"].head(11)
# Out:
# 0     127.0
# 1     100.0
# 2       NaN
# 3       NaN
# 4     118.0
# 5     112.0
# 6      96.0
# 7     121.0
# 8      97.0
# 9      98.0
# 10    105.0
# Name: magnesium, dtype: float64

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine["alcohol"].fillna(10,inplace=True)
wine["magnesium"].fillna(100,inplace=True)
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.71               15.6      127.0        3.06
# 1      10.00        1.78               11.2      100.0        2.76
# 2      10.00        2.36               18.6      100.0        3.24
# 3      14.37        1.95               16.8      100.0        3.49
# 4      13.24        2.59               21.0      118.0        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5       95.0        0.61
# 174    13.40        3.91               23.0      102.0        0.75
# 175    13.27        4.28               20.0      120.0        0.69
# 176    13.17        2.59               20.0      120.0        0.68
# 177    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### Step 9. Count the number of missing values in all columns.

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10 and save it.

# %%
random=np.random.randint(1,10,10)
random
# Out:
# array([5, 2, 1, 7, 4, 4, 9, 3, 8, 9])

# %% [markdown]
# ### Step 11.  Set the rows Alternate rows of alcohol column to the  NaN

# %%
wine.alcohol.iloc[::2] = np.NAN
print(wine["alcohol"])
# Out:
# 0        NaN
# 1      10.00
# 2        NaN
# 3      14.37
# 4        NaN
#        ...
# 173    13.71
# 174      NaN
# 175    13.27
# 176      NaN
# 177    14.13
# Name: alcohol, Length: 178, dtype: float64

# %% [markdown]
# ### Step 12.  How many missing values do we have now?

# %%
wine.isnull().sum().sum()
# Out:
# 89

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine=wine.dropna()
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 1      10.00        1.78               11.2      100.0        2.76
# 3      14.37        1.95               16.8      100.0        3.49
# 5      14.20        1.76               15.2      112.0        3.39
# 7      14.06        2.15               17.6      121.0        2.51
# 9      13.86        1.35               16.0       98.0        3.15
# ..       ...         ...                ...        ...         ...
# 169    13.40        4.60               25.0      112.0        0.96
# 171    12.77        2.39               19.5       86.0        0.51
# 173    13.71        5.65               20.5       95.0        0.61
# 175    13.27        4.28               20.0      120.0        0.69
# 177    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 1               1.28  1.05
# 3               2.18  0.86
# 5               1.97  1.05
# 7               1.25  1.06
# 9               1.85  1.01
# ..               ...   ...
# 169             1.11  0.67
# 171             0.64  0.57
# 173             1.06  0.64
# 175             1.35  0.59
# 177             1.35  0.61
#
# [89 rows x 7 columns]

# %% [markdown]
# ### Step 14.  Reset the index, so it starts with 0 again

# %%
wine.reset_index()
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.71               15.6      127.0        3.06
# 1      10.00        1.78               11.2      100.0        2.76
# 2        NaN        2.36               18.6      100.0        3.24
# 3      14.37        1.95               16.8      100.0        3.49
# 4        NaN        2.59               21.0      118.0        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5       95.0        0.61
# 174      NaN        3.91               23.0      102.0        0.75
# 175    13.27        4.28               20.0      120.0        0.69
# 176      NaN        2.59               20.0      120.0        0.68
# 177    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %%
_
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.71               15.6      127.0        3.06
# 1      10.00        1.78               11.2      100.0        2.76
# 2        NaN        2.36               18.6      100.0        3.24
# 3      14.37        1.95               16.8      100.0        3.49
# 4        NaN        2.59               21.0      118.0        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5       95.0        0.61
# 174      NaN        3.91               23.0      102.0        0.75
# 175    13.27        4.28               20.0      120.0        0.69
# 176      NaN        2.59               20.0      120.0        0.68
# 177    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]
